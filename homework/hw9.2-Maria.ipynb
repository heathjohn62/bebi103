# %% [markdown]
# <br />

# %% [markdown]
# ### Problem 9.2: Outliers in FRET binding curve, 20 pts
#
# We often want to ascertain how tightly two proteins are bound by measuring their dissociation constant, $K_d$.  This is usually done by doing a titration experiment and then performing a regression.  For example, imagine two proteins, a and b may bind to each other in the reaction
#
# \begin{align}
# \text{ab} \rightleftharpoons \text{a} + \text{b}
# \end{align}
#
# with dissociation constant $K_d$.  At equilibrium
#
# \begin{align}
# K_d = \frac{c_a\,c_b}{c_{ab}},
# \end{align}
#
# were $c_i$ is the concentration of species $i$.  If we add known amounts of a and b to a solution such that the total concentration of a is $c_a^0$ and the total concentration of b is $c_b^0$, we can compute the equilibrium concentrations of all species.  Specifically, in addition to the equation above, we have conservation of mass equations,
#
# \begin{align}
# c_a^0 &= c_a + c_{ab}\\[1em]
# c_b^0 &= c_b + c_{ab},
# \end{align}
#
# fully specifying the problem.  We can solve the three equations for $c_{ab}$ in terms of the known quantities $c_a^0$ and $c_b^0$, along with the parameter we are trying to measure, $K_d$.  We get
#
# \begin{align}
# c_{ab} = \frac{2c_a^0\,c_b^0}{K_d+c_a^0+c_b^0 + \sqrt{\left(K_d+c_a^0+c_b^0\right)^2 - 4c_a^0\,c_b^0}}.
# \end{align}
#
# The technique, then, is to hold $c_a^0$ fixed in the experiment and measure $c_{ab}$ for various $c_b^0$. We can then perform a regression to get $K_d$.
#
# In order to do this, though, we need some readout of $c_{ab}$. For this problem, we will use FRET (fluorescence resonance energy transfer) to monitor how much of a is bound to b.  Specifically, we consider a to have a fluorophore and b to be its receptor.  When the two are unbound, we get a fluorescence signal per molecule of $f_0$.  When they are bound, the receptor absorbs the light coming out of the fluorophore, so we get less fluorescence per molecule, which we will call $f_q$ (for "quenched").  Let $f$ be the total per-fluorophore fluorescence signal.  Then, the measured fluorescence signal, $F$, is
#
# \begin{align}
# F = c_a^0\,V f = \left(c_a \,f_0 + c_{ab}\, f_q\right)V,
# \end{align}
#
# where $V$ is the reaction volume. We can absorb $V$ into the other parameters such that $\hat{f}_0 = f_0 V$ and $\hat{f}_q = f_q V$, giving
#
# \begin{align}
# F = \hat{f}_0(c_a^0 - c_{ab}) + \hat{f}_q\, c_{ab}
# = \hat{f}_0\,c_a^0 - \frac{2(\hat{f}_0 - \hat{f}_q)c_a^0\,c_b^0}{K_d+c_a^0+c_b^0 + \sqrt{\left(K_d+c_a^0+c_b^0\right)^2 - 4c_a^0\,c_b^0}}.
# \end{align}
#
# Compute parameter estimates for $K_d$ with and without an outlier detection scheme for [this data set](../data/fret_binding_curve.csv). How do the results differ depending on whether or not you were trying to detect outliers?
#
# *Note*: These are real data, but they are from an unpublished experiment here on campus. I therefore have not exposed the identities of the proteins a and b.

# %%
import glob
import os
import sys

import numpy as np
import pandas as pd
import scipy.signal

# Import Altair for high level plotting
import altair as alt
import altair_catplot as altcat

# Pevent bulky altair plots
alt.data_transformers.enable('json')

import bebi103
import bokeh
from bokeh.palettes import all_palettes
import itertools
from bokeh.models import Legend, LegendItem
bokeh.io.output_notebook()
# Out:
# /home/ec2-user/miniconda/lib/python3.7/site-packages/bebi103/viz.py:30: UserWarning: DataShader import failed with error "No module named 'datashader'".
# Features requiring DataShader will not work and you will get exceptions.
#   Features requiring DataShader will not work and you will get exceptions.""")
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1e1e247e-a9f5-4c29-b58f-a8f102fddccb">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv("/home/ec2-user/data/fret_binding_curve.csv", comment = '#')
df
# Out:
#       buffer  fluorescence  a conc (nM)  b conc (nM)
# 0  1256.5751   258316.2818         50.0  1500.000000
# 1  1256.5751   267722.6277         50.0   750.000000
# 2  1256.5751   267431.6620         50.0   375.000000
# 3  1256.5751   284596.2914         50.0   187.500000
# 4  1256.5751   254903.3958         50.0    93.750000
# 5  1256.5751   333810.6371         50.0    46.875000
# 6  1256.5751   370821.7778         50.0    23.437500
# 7  1256.5751   408856.1424         50.0    11.718750
# 8  1256.5751   431000.0000         50.0     5.859375
# 9  1256.5751   437000.0000         50.0     0.000000

# %%
alt.Chart(df).mark_point().encode(
    x = alt.X("b conc (nM)"),
    y = alt.Y("fluorescence"))
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# LOL I wonder if there are any outliers

# %% [markdown]
# Given our known quantities and our goal, the relevant equation is:
# \begin{align}
# F
# = \hat{f}_0\,c_a^0 - \frac{2(\hat{f}_0 - \hat{f}_q)c_a^0\,c_b^0}{K_d+c_a^0+c_b^0 + \sqrt{\left(K_d+c_a^0+c_b^0\right)^2 - 4c_a^0\,c_b^0}}.
# \end{align}

# %% [markdown]
# The concentration of a is a set quantity in this experiment and that of b is our independent variabl, so we need parameter estimates of $K_d$, $\hat{f}_0$, and $\hat{f}_q$. Additionally we want to include a Gaussian error term $\sigma$ to reflect errors in measurement. Our priors are as follows:

# %% [markdown]
# $$\text{fl} = \text{Norm}(F(c_a^0), \sigma).$$

# %%
data = dict(N=len(df),
           cb=df['b conc (nM)'].values.astype(float))

# %% [markdown]
# $K_d$ ~ lognorm(1, 3) Given our (limited) knowledge of dissociation constants, we expect $K_d$ to be very small, but do no know the order of magnitude, so we will use a log-normal distribution
#
# $\hat{f}_0$ ~ Norm(500000, 50000) Flourescence is an ununited relative value, but in this experiment it appears to be between 100000 and 500000, so we will choose a distribution with a wide variation at the top of this scale
#
# $\hat{f}_q$ ~ Norm(50000, 5000) We expect quenched molecules to have a much smaller fluorescence than the unquenched molecules, so we will choose a distribution an order of magnitude smaller than that of $\hat{f}_0$
#
# $\sigma$ ~ Half-Norm(0, .5): We expect a variability in measurement of about .1, and to vary from that by about .1.
#
# Additionally, we know that
# $c_a^0$ = 50 nM

# %%
sm = bebi103.stan.StanModel(file='./9.2_prior.stan')
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_aedbf8ec8e2756c5ef06d2b94e077559 NOW.
# /home/ec2-user/miniconda/lib/python3.7/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpantm9cr1/stanfit4anon_model_aedbf8ec8e2756c5ef06d2b94e077559_4703190534982069862.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name
df_gen_fl = df_gen_fl.sort_index(level=1)


# Renaming the columns with useful names
df_gen_fl = df_gen_fl.rename(columns={'level_0': 'model', 
                                  'level_1': 'cb',
                                  0:'fluorescence signal'})

# Renaming the conditions with more descriptive names
for i in range(len(cols)):
    df_gen_fl = df_gen_fl.replace({cols[i]:data['cb'][i]})

# %%
df_gen_fl.head()
# Out:
#    model       cb  fluorescence signal
# 0      0  1500.00         45075.818423
# 1      0   750.00         47502.668725
# 2      0   375.00         48118.754863
# 3      0   187.50         51139.338826
# 4      0    93.75         65473.783005

# %%
alt.Chart(df_gen_fl).mark_line().encode(
    x = alt.X('cb'),
    y = alt.Y('fluorescence signal'),
    color = alt.Color('model'))
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
sm2 = bebi103.stan.StanModel(file='./9.2_model.stan')
# Out:
# Using cached StanModel.

# %%
data = dict(N=len(df),
           cb=df['b conc (nM)'].values.astype(float))

# %%
samples2 = sm2.sampling(data=data)
# Out:
# WARNING:pystan:n_eff / iter for parameter f0 is 0.0006932633893010355!
# WARNING:pystan:n_eff / iter for parameter fq is 0.0005081431525390151!
# WARNING:pystan:n_eff / iter for parameter sigma is 0.0008708218884531885!
# WARNING:pystan:n_eff / iter for parameter fl[1] is 0.0007040725440007903!
# WARNING:pystan:n_eff / iter for parameter fl[2] is 0.0007033439467817541!
# WARNING:pystan:n_eff / iter for parameter fl[3] is 0.0007007730979028776!
# WARNING:pystan:n_eff / iter for parameter fl[4] is 0.0006981218997431779!
# WARNING:pystan:n_eff / iter for parameter fl[5] is 0.0006960786979947905!
# WARNING:pystan:n_eff / iter for parameter fl[6] is 0.0006947511473280048!
# WARNING:pystan:n_eff / iter for parameter fl[7] is 0.0006940115446769154!
# WARNING:pystan:n_eff / iter for parameter fl[8] is 0.0006936556033581855!
# WARNING:pystan:n_eff / iter for parameter fl[9] is 0.0006934219289249801!
# WARNING:pystan:n_eff / iter for parameter fl[10] is 0.0006932883813754947!
# WARNING:pystan:n_eff / iter for parameter F[1] is 0.0007040908978688155!
# WARNING:pystan:n_eff / iter for parameter F[2] is 0.0007034395812266478!
# WARNING:pystan:n_eff / iter for parameter F[3] is 0.0007008395667185245!
# WARNING:pystan:n_eff / iter for parameter F[4] is 0.0006981050219516652!
# WARNING:pystan:n_eff / iter for parameter F[5] is 0.0006960479152771405!
# WARNING:pystan:n_eff / iter for parameter F[6] is 0.0006947595744608455!
# WARNING:pystan:n_eff / iter for parameter F[7] is 0.000694037833123126!
# WARNING:pystan:n_eff / iter for parameter F[8] is 0.0006936567242646626!
# WARNING:pystan:n_eff / iter for parameter F[9] is 0.0006934614473769113!
# WARNING:pystan:n_eff / iter for parameter F[10] is 0.0006932633893010356!
# WARNING:pystan:n_eff / iter for parameter ca is nan!
# WARNING:pystan:n_eff / iter for parameter fl_ppc[1] is 0.0007040994898593332!
# WARNING:pystan:n_eff / iter for parameter fl_ppc[2] is 0.0007034461546012904!
# WARNING:pystan:n_eff / iter for parameter fl_ppc[3] is 0.0007008745014169163!
# WARNING:pystan:n_eff / iter for parameter fl_ppc[4] is 0.0006981398837908156!
# WARNING:pystan:n_eff / iter for parameter fl_ppc[5] is 0.0006960743285588911!
# WARNING:pystan:n_eff / iter for parameter fl_ppc[6] is 0.0006947305682455831!
# WARNING:pystan:n_eff / iter for parameter fl_ppc[7] is 0.0006939680451170135!
# WARNING:pystan:n_eff / iter for parameter fl_ppc[8] is 0.0006936706472552192!
# WARNING:pystan:n_eff / iter for parameter fl_ppc[9] is 0.0006934955384255201!
# WARNING:pystan:n_eff / iter for parameter fl_ppc[10] is 0.0006932320443561884!
# WARNING:pystan:n_eff / iter for parameter lp__ is 0.0005724657523012183!
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat for parameter Kd is 1.1434472887487208!
# WARNING:pystan:Rhat for parameter f0 is 4.0899469991879185!
# WARNING:pystan:Rhat for parameter fq is 7.875167713837614!
# WARNING:pystan:Rhat for parameter sigma is 1.6395428308952238!
# WARNING:pystan:Rhat for parameter fl[1] is 3.7526960515411556!
# WARNING:pystan:Rhat for parameter fl[2] is 3.901722167567851!
# WARNING:pystan:Rhat for parameter fl[3] is 3.982213900257173!
# WARNING:pystan:Rhat for parameter fl[4] is 4.02786553881643!
# WARNING:pystan:Rhat for parameter fl[5] is 4.056088354629144!
# WARNING:pystan:Rhat for parameter fl[6] is 4.072159353392482!
# WARNING:pystan:Rhat for parameter fl[7] is 4.080492334749612!
# WARNING:pystan:Rhat for parameter fl[8] is 4.085558331789319!
# WARNING:pystan:Rhat for parameter fl[9] is 4.087809467917423!
# WARNING:pystan:Rhat for parameter fl[10] is 4.089617372427646!
# WARNING:pystan:Rhat for parameter F[1] is 3.7521258644675415!
# WARNING:pystan:Rhat for parameter F[2] is 3.901167174024197!
# WARNING:pystan:Rhat for parameter F[3] is 3.9817308077046807!
# WARNING:pystan:Rhat for parameter F[4] is 4.0283045689033905!
# WARNING:pystan:Rhat for parameter F[5] is 4.056089019498031!
# WARNING:pystan:Rhat for parameter F[6] is 4.072051571926301!
# WARNING:pystan:Rhat for parameter F[7] is 4.080738387960858!
# WARNING:pystan:Rhat for parameter F[8] is 4.085278610049523!
# WARNING:pystan:Rhat for parameter F[9] is 4.087597584714019!
# WARNING:pystan:Rhat for parameter F[10] is 4.08994699918792!
# WARNING:pystan:Rhat for parameter ca is nan!
# WARNING:pystan:Rhat for parameter log_like[1] is 1.5815779566115489!
# WARNING:pystan:Rhat for parameter log_like[2] is 1.582965028084237!
# WARNING:pystan:Rhat for parameter log_like[3] is 1.584533797518454!
# WARNING:pystan:Rhat for parameter log_like[4] is 1.5827954748331248!
# WARNING:pystan:Rhat for parameter log_like[5] is 1.582544672766253!
# WARNING:pystan:Rhat for parameter log_like[6] is 1.582860027429749!
# WARNING:pystan:Rhat for parameter log_like[7] is 1.5826598017389297!
# WARNING:pystan:Rhat for parameter log_like[8] is 1.584106013266646!
# WARNING:pystan:Rhat for parameter log_like[9] is 1.583348929955013!
# WARNING:pystan:Rhat for parameter log_like[10] is 1.5835673428316153!
# WARNING:pystan:Rhat for parameter fl_ppc[1] is 3.7522050976200156!
# WARNING:pystan:Rhat for parameter fl_ppc[2] is 3.9011443860415422!
# WARNING:pystan:Rhat for parameter fl_ppc[3] is 3.981820254507074!
# WARNING:pystan:Rhat for parameter fl_ppc[4] is 4.02776129360063!
# WARNING:pystan:Rhat for parameter fl_ppc[5] is 4.055966334266208!
# WARNING:pystan:Rhat for parameter fl_ppc[6] is 4.072639051453821!
# WARNING:pystan:Rhat for parameter fl_ppc[7] is 4.081441504197784!
# WARNING:pystan:Rhat for parameter fl_ppc[8] is 4.085189296626135!
# WARNING:pystan:Rhat for parameter fl_ppc[9] is 4.08746845119513!
# WARNING:pystan:Rhat for parameter fl_ppc[10] is 4.089915930218893!
# WARNING:pystan:Rhat for parameter lp__ is 3.9012250306804224!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:2090 of 4000 iterations ended with a divergence (52.25%).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:377 of 4000 iterations saturated the maximum tree depth of 10 (9.425%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 2: E-BFMI = 0.18894235468829698
# WARNING:pystan:Chain 4: E-BFMI = 0.1012911394483021
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model

# %%
df2 = bebi103.stan.to_dataframe(samples2, diagnostics=False, inc_warmup=False)

# %%
df2.tail()
# Out:
#       chain  chain_idx  warmup           Kd             f0            fq  \
# 3995      4        996       0  7805.683387  394964.544365  56404.360304
# 3996      4        997       0  7594.862199  395111.962345  55376.575002
# 3997      4        998       0  7609.292624  395174.351077  55403.866235
# 3998      4        999       0  6391.007576  409159.708958  50993.459520
# 3999      4       1000       0  6411.739740  409076.270130  50775.159956
#
#             sigma         fl[1]         fl[2]         fl[3]     ...      \
# 3995  9086.819494  1.701526e+07  1.828765e+07  1.897335e+07     ...
# 3996  9003.590914  1.695676e+07  1.825849e+07  1.896019e+07     ...
# 3997  8998.239213  1.698520e+07  1.822796e+07  1.895695e+07     ...
# 3998  4362.163767  1.707919e+07  1.859215e+07  1.947683e+07     ...
# 3999  4463.413217  1.707553e+07  1.859042e+07  1.948009e+07     ...
#
#          fl_ppc[2]     fl_ppc[3]     fl_ppc[4]     fl_ppc[5]     fl_ppc[6]  \
# 3995  1.827723e+07  1.895354e+07  1.935643e+07  1.955599e+07  1.963680e+07
# 3996  1.823310e+07  1.894648e+07  1.936702e+07  1.957309e+07  1.964541e+07
# 3997  1.825139e+07  1.896634e+07  1.934584e+07  1.954256e+07  1.963379e+07
# 3998  1.859180e+07  1.947516e+07  1.994609e+07  2.020411e+07  2.033182e+07
# 3999  1.859209e+07  1.947022e+07  1.994828e+07  2.019754e+07  2.032504e+07
#
#          fl_ppc[7]     fl_ppc[8]     fl_ppc[9]    fl_ppc[10]        lp__
# 3995  1.970491e+07  1.972492e+07  1.973150e+07  1.974735e+07 -104.867085
# 3996  1.972451e+07  1.973979e+07  1.973827e+07  1.976181e+07 -105.000605
# 3997  1.969529e+07  1.973392e+07  1.975371e+07  1.976277e+07 -101.777214
# 3998  2.038611e+07  2.042678e+07  2.044513e+07  2.046522e+07  -93.674691
# 3999  2.039544e+07  2.042549e+07  2.043835e+07  2.046095e+07  -94.880267
#
# [5 rows x 49 columns]
