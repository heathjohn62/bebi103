# %% [markdown]
# # Tutorial 5: exercise
#
# (c) 2018 Justin Bois. With the exception of pasted graphics, where the source is noted, this work is licensed under a [Creative Commons Attribution License CC-BY 4.0](https://creativecommons.org/licenses/by/4.0/). All code contained herein is licensed under an [MIT license](https://opensource.org/licenses/MIT).
#
# This document was prepared at [Caltech](http://www.caltech.edu) with financial support from the [Donna and Benjamin M. Rosen Bioengineering Center](http://rosen.caltech.edu).
#
# <img src="caltech_rosen.png">
#
# *This tutorial exercise was generated from an Jupyter notebook.  You can download the notebook [here](t5_exercise.ipynb). Use this downloaded Jupyter notebook to fill out your responses.*

# %% [markdown]
# ### Exercise 1
#
# What is the plug-in principle and how is it used in non-parametric statistics?

# %% [markdown]
# The plug-in principle is a method of estimating functional for a sample by computing the functionals using the empirical distribution of the sample. It is used to estimate parameters in non-parametric statistics based on the empirical distribution, so without assuming a model distribution.

# %% [markdown]
# ### Exercise 2
#
# What is a bootstrap sample and what is a bootstrap replicate?

# %% [markdown]
# A bootstrap sample is a sample gathered from a data set by drawing random data points from the data set with replacement to form a new sample the size of the original data set. A bootstrap replicate is a statistic of interest calculated from a bootstrap sample rather than the original sample.

# %% [markdown]
# ### Exercise 3
#
# Consider the following data set for waiting times in minutes for nuclear localization events of the gene MSN-2 in yeast (these are real measurements done by Yihan Lin in Michael Elowitz's lab).

# %%
t = [3, 6, 11, 5, 5, 4, 73, 31, 7, 6, 
     30, 4, 32, 30, 5, 53, 2, 15, 18, 
     14, 3, 49, 7, 4, 4, 2, 9, 11, 8, 
     5, 14, 6, 32, 40, 3, 5, 24]

# %% [markdown]
# You suspect that MSN-2 localization may be a Poisson process and therefore that these waiting times are Exponentially distributed with a characteristic wait time of 20 minutes. Do a quick graphical analysis to check out this idea.

# %%
import numpy as np
import pandas as pd
import scipy.special
import scipy.stats as st

import pystan

import bebi103

import altair as alt
import altair_catplot as altcat

import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# /Users/maria/anaconda/lib/python3.6/site-packages/bebi103/viz.py:30: UserWarning: DataShader import failed with error "No module named 'datashader'".
# Features requiring DataShader will not work and you will get exceptions.
#   Features requiring DataShader will not work and you will get exceptions.""")
# /Users/maria/anaconda/lib/python3.6/site-packages/bebi103/viz.py:38: UserWarning: Could not import `stan` submodule. Perhaps pystan is not properly installed.
#   warnings.warn('Could not import `stan` submodule. Perhaps pystan is not properly installed.')
# /Users/maria/anaconda/lib/python3.6/site-packages/bebi103/__init__.py:19: UserWarning: Could not import `stan` submodule. Perhaps pystan is not properly installed.
#   warnings.warn('Could not import `stan` submodule. Perhaps pystan is not properly installed.')
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="29c5bde9-d1e7-45e6-b775-7de37827d27a">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# First let's make ourselves an exponential distribution of the same size as our dataset. We'll set the parameter as 1 to start.

# %%
t_gen = np.random.exponential(scale = 1, size=len(t))

# %% [markdown]
# Let's display both t and t_gen on the same graph.

# %%
p = bebi103.viz.ecdf(t, x_axis_label='Waiting Times', formal=True, line_width=2)
p = bebi103.viz.ecdf(t_gen, p=p, color='gray', formal=True, line_width=2)

bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3
type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"93783c67-24e5-42ed-95a8-ebff0fceba52","type":"PanTool"},{"id":"480f8b68-1e03-41be-b365-9afb5693f2ee","type":"WheelZoomTool"},{"id":"86f9b045-8a99-4056-b59b-a94807a1a595","type":"BoxZoomTool"},{"id":"c048b8e1-4dae-404c-a8bd-a6779f3197ad","type":"SaveTool"},{"id":"e6424a18-98cc-4cdb-8282-068e5dcf03b5","type":"ResetTool"},{"id":"47e7f7c1-b4ee-4a47-b88c-a556df00ace6","type":"HelpTool"}]},"id":"a3d008ab-2ebf-4857-a45c-4a27f7509490","type":"Toolbar"},{"attributes":{"callback":null},"id":"9c8a8c88-6086-48a1-8b87-1fd83a0b98e8","type":"ColumnDataSource"},{"attributes":{"angle":{"units":"rad","value":0},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"value":73.0},"y":{"value":1}},"id":"0d635ed5-7715-471e-a3f8-5304d5ff5bab","type":"Ray"},{"attributes":{"angle":{"units":"rad","value":3.141592653589793},"line_color":{"value":"#1f77b4"},"line_width":{ ...

# %% [markdown]
# Those don't look the same, but then our data set doesn't seem to have an average at 1, so we'd be surprised if that worked. Let's try again, using the mean of our data set as our parameter:

# %%
mean = np.mean(t)
t_gen = np.random.exponential(scale = mean, size=len(t))
p = bebi103.viz.ecdf(t, x_axis_label='Waiting Times', formal=True, line_width=2)
p = bebi103.viz.ecdf(t_gen, p=p, color='gray', formal=True, line_width=2)

bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fdc1c030-8106-4b7b-b378-49da4ebf7f6b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("fdc1c030-8106-4b7b-b378-49da4ebf7f6b").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fdc1c030-8106-4b7b-b378-49da4ebf7f6b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fdc1c030-8106-4b7b-b378-49da4ebf7f6b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3c95099b-47fd-4ccf-8cfb-530db45c1f60":{"roots":{"references":[{"attributes":{"plot":{"id":"ba54b6ac-6634-4301-a46a-0b9483118390","subtype":"Figure","type":"Plot"}},"id":"25128876-195f-4171-88d3-fa67eed7513e","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"fc47d780-1fe1-4473-81cf-ae36a9d0e41d","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ba54b6ac-6634-4301-a46a-0b9483118390","subtype":"Figure","type":"Plot"}},"id":"9a726536-68b8-4c2a-a0e9-ecc8feb16b0f","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"fc47d780-1fe1-4473-81cf-ae36a9d0e41d","type":"BoxAnnotation"},"plot":{"id":"ba54b6ac-6634-4301-a46a-0b9483118390","subtype":"Figure","type":"Plot"}},"id":"e6c75053-9af0-4891-be8f-78c01da3b1e6","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"ba54b6ac-6634-4301-a46a-0b9483118390","subtype":"Figure","type":"Plot"}},"id":"4bba5107-f0dd-4607-afaf-02d2c413adfe","type":"SaveTool"},{"attributes":{"plot":{"id":"ba54b6ac-6634-4301-a46a-0b9483118390","subtype":"Figure","type":"Plot"}},"id":"9d092195-1e64-47fe-94c2-7802f809baf7","type":"ResetTool"},{"attributes":{"plot":{"id":"ba54b6ac-6634-4301-a46a-0b9483118390","subtype":"Figure","type":"Plot"}},"id":"0b4cf827-d0e4-4e21-9fe4-39733425f212","type":"HelpTool"},{"attributes":{"angle":{"units":"rad","value":3.141592653589793},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"value":2.0},"y":{"value":0}},"id":"2c19c13e-8554-4b00-8028-1f55e24dcee0","type":"Ray"},{"attributes":{"callback":null},"id":"99fa7b88-1f2f-4a28-b7c6-c63f2b7cef6c","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"99fa7b88-1f2f-4a28-b7c6-c63f2b7cef6c","type":"ColumnDataSource"},"glyph":{"id":"2c19c13e-8554-4b00-8028-1f55e24dcee0","type":"Ray"},"hover_glyph":null,"nonselection_glyph":{"id":"c33629be-ed75-4db1-ae39-d4c9dbbc8a6f","type":"Ray"},"selection_glyph":null},"id":"3387545f-2cd1-48bc-91a4-f0f2ce668180","type":"GlyphRenderer"},{"attributes":{"angle":{"units":"rad","value":3.141592653589793},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"value":2.0},"y":{"value":0}},"id":"c33629be-ed75-4db1-ae39-d4c9dbbc8a6f","type":"Ray"},{"attributes":{"callback":null},"id":"3b062fb0-21bc-48e7-8f33-bcd46aae9950","type":"ColumnDataSource"},{"attributes":{"angle":{"units":"rad","value":0},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"value":73.0},"y":{"value":1}},"id":"a1b471a1-e4f4-4815-9fa3-d865d31b7416","type":"Ray"},{"attributes":{"angle":{"units":"rad","value":0},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"value":73.0},"y":{"value":1}},"id":"058e5a69-7a5c-439f-a270-21714edac7a4","type":"Ray"},{"attributes":{"data_source":{"id":"3b062fb0-21bc-48e7-8f33-bcd46aae9950","type":"ColumnDataSource"},"glyph":{"id":"a1b471a1-e4f4-4815-9fa3-d865d31b7416","type":"Ray"},"hover_glyph":null,"nonselection_glyph":{"id":"058e5a69-7a5c-439f-a270-21714edac7a4","type":"Ray"},"selection_glyph":null},"id":"88eb046d-2e2c-4b27-a570-86edad1cbc5d","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"gray"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"55fa2b1c-ddc2-4437-96f4-80edb016d75c","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"d2d026a2-c068-4feb-bd4b-ff710a7cf450","type":"Line"},{"attributes":{"data_source":{"id":"5f0bef9f-4099-45fd-92b4-2491119c1289","type":"ColumnDataSource"},"glyph":{"id":"55fa2b1c-ddc2-4437-96f4-80edb016d75c","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"d2d026a2-c068-4feb-bd4b-ff710a7cf450","type":"Line"}," ...

# %% [markdown]
# Those look similar, but I'm not certain. Let's try to make many plots from our exponential distribution and see if it looks better:

# %%
p = bebi103.viz.ecdf(t_gen, x_axis_label='Waiting Times', color='gray', alpha=0.1, formal=True)
 
for _ in range(100):
    t_gen = np.random.exponential(scale = mean, size=len(t))
    p = bebi103.viz.ecdf(t_gen, p=p, color='gray', alpha=0.1, formal=True)
    
p = bebi103.viz.ecdf(t, p=p, formal=True, line_width=2)

bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f3c583c2-f2eb-46ce-8e68-e8cb3a1d5868"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f3c583c2-f2eb-46ce-8e68-e8cb3a1d5868").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f3c583c2-f2eb-46ce-8e68-e8cb3a1d5868");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f3c583c2-f2eb-46ce-8e68-e8cb3a1d5868' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e3ae8647-21a8-4066-89e3-8b3ceff21232":{"roots":{"references":[{"attributes":{"angle":{"units":"rad","value":3.141592653589793},"line_alpha":{"value":0.1},"line_color":{"value":"gray"},"x":{"value":0.06028206640794849},"y":{"value":0}},"id":"8ae7457d-2984-47bc-8cc5-90fa51ee16f8","type":"Ray"},{"attributes":{"angle":{"units":"rad","value":3.141592653589793},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"value":0.8035524474508554},"y":{"value":0}},"id":"aae8c7b0-c789-4999-9db1-4c30d9ea371c","type":"Ray"},{"attributes":{"data_source":{"id":"279cd346-d824-4349-95e8-34b166f0d30f","type":"ColumnDataSource"},"glyph":{"id":"e23318f3-1c7c-46c6-aac9-33bc29bf53f1","type":"Ray"},"hover_glyph":null,"nonselection_glyph":{"id":