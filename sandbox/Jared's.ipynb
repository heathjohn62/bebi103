# %%
import itertools

# Our numerical workhorses
import numpy as np
import pandas as pd
import scipy.integrate

# Import Altair for high level plotting
import altair as alt
import altair_catplot as altcat

# Import Bokeh modules for interactive plotting
import bokeh.io
import bokeh.plotting

# Set up Bokeh for inline viewing
bokeh.io.output_notebook()

# Pevent bulky altair plots
alt.data_transformers.enable('json')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a7b24217-05b7-49b1-b7ee-421ca0c2473f">Loading BokehJS ...</span>
#     </div>
# DataTransformerRegistry.enable('json')

# %%
df = pd.read_csv('../data/fish_actvity_for_validation/150717_2A_2B.csv', comment='#')

# %%
# Out:
# location,animal,user,sn,an,datatype,start,end,startreason,endreason,frect,fredur,midct,middur,burct,burdur,stdate,sttime
# c97,z097,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,34,55.7,34,4.3,0,0,17/07/2015,14:30:00
# c98,z098,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,0,60,0,0,0,0,17/07/2015,14:30:00
# c99,z099,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,6,59,6,1,0,0,17/07/2015,14:30:00
# c100,z100,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,25,55.8,25,4.2,0,0,17/07/2015,14:30:00
# c101,z101,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,1,60,0,0,0,0,17/07/2015,14:30:00
# c102,z102,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,0,60,0,0,0,0,17/07/2015,14:30:00
# c103,z103,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,10,58.3,10,1.7,0,0,17/07/2015,14:30:00
# c104,z104,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,38,53.4,39,6.6,0,0,17/07/2015,14:30:00
# c105,z105,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,0,60,0,0,0,0,17/07/2015,14:30:00
# c106,z106,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,21,56.4,22,3.6,1,0.1,17/07/2015,14:30:00
# c107,z107,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,1,60,0,0,0,0,17/07/2015,14:30:00
# c108,z108,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,12,57.5,12,2.6,0,0,17/07/2015,14:30:00
# c109,z109,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,10,58.9,10,1.1,0,0,17/07/2015,14:30:00
# c110,z110,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,9,58.1,9,1.9,0,0,17/07/2015,14:30:00
# c111,z111,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,1,60,1,0.1,0,0,17/07/2015,14:30:00
# c112,z112,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,31,55.6,32,4.5,0,0,17/07/2015,14:30:00
# c113,z113,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,0,60,0,0,0,0,17/07/2015,14:30:00
# c114,z114,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,1,60,0,0,0,0,17/07/2015,14:30:00
# c115,z115,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,33,54.2,33,5.8,0,0,17/07/2015,14:30:00
# c116,z116,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,9,58.4,9,1.7,0,0,17/07/2015,14:30:00
# c117,z117,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,23,54.5,23,5.6,0,0,17/07/2015,14:30:00
# c118,z118,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,8,59.2,8,0.9,0,0,17/07/2015,14:30:00
# c119,z119,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,1,60,1,0.1,0,0,17/07/2015,14:30:00
# c120,z120,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,63,50.3,64,9.7,1,0.1,17/07/2015,14:30:00
# c121,z121,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,2,59.9,2,0.1,0,0,17/07/2015,14:30:00
# c122,z122,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,4,59.4,4,0.7,0,0,17/07/2015,14:30:00
# c123,z123,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,19,56.7,19,3.4,0,0,17/07/2015,14:30:00
# c124,z124,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,0,60,0,0,0,0,17/07/2015,14:30:00
# c125,z125,ZEBRALAB02\zebralab_user,1,0,quant,0,60,Beginning of session,End of period,0,60,0,0,0,0,17/07/2015,14:30:00
